# %%
import os
import rasterio
from rasterio.enums import Compression
from tqdm import tqdm

# Set your folder path
input_folder = r"G:\Public\GLC_FCS30D\Before_20th_Centry\1990s"
output_folder = os.path.join(input_folder, "compressed")  # Save compressed files here
os.makedirs(output_folder, exist_ok=True)

# Loop over years 1988 to 2020 (last file is 2020–2021)
for year in tqdm(range(1990, 2022)):
    input_filename = f"LCMAP_CU_{year}_V13_LCPRI_EuclideanDepth.tif"
    input_path = os.path.join(input_folder, input_filename)
    
    if not os.path.exists(input_path):
        print(f"Missing file: {input_path}")
        continue

    output_path = os.path.join(output_folder, input_filename)

    # Open and re-save with LZW compression
    with rasterio.open(input_path) as src:
        profile = src.profile
        profile.update(compress='lzw')

        with rasterio.open(output_path, 'w', **profile) as dst:
            for i in range(1, src.count + 1):
                dst.write(src.read(i), i)

print("✅ Compression completed. Compressed files saved to:", output_folder)

# %%
import os
import rasterio
from rasterio.enums import Compression
from tqdm import tqdm

# Set input and output folder paths
input_folder = r"G:\Public\GLC_FCS30D\Before_20th_Centry\1990s"
output_folder = os.path.join(input_folder, "compressed")
os.makedirs(output_folder, exist_ok=True)

# Loop through all .tif files in the folder
tif_files = [f for f in os.listdir(input_folder) if f.lower().endswith(".tif")]

for filename in tqdm(tif_files, desc="Compressing TIFFs"):
    input_path = os.path.join(input_folder, filename)
    output_path = os.path.join(output_folder, filename)

    with rasterio.open(input_path) as src:
        profile = src.profile
        profile.update(compress='lzw')

        with rasterio.open(output_path, 'w', **profile) as dst:
            for i in range(1, src.count + 1):
                dst.write(src.read(i), i)

print("✅ All GeoTIFFs compressed and saved to:", output_folder)

# %%
import os
import rasterio
from rasterio.enums import Compression
from tqdm import tqdm

# Set input and output folder paths
input_folder = r"G:\Public\GLC_FCS30D\Before_20th_Centry\1995s"
output_folder = os.path.join(input_folder, "compressed")
os.makedirs(output_folder, exist_ok=True)

# Loop through all .tif files in the folder
tif_files = [f for f in os.listdir(input_folder) if f.lower().endswith(".tif")]

for filename in tqdm(tif_files, desc="Compressing TIFFs"):
    input_path = os.path.join(input_folder, filename)
    output_path = os.path.join(output_folder, filename)

    with rasterio.open(input_path) as src:
        profile = src.profile
        profile.update(compress='lzw')

        with rasterio.open(output_path, 'w', **profile) as dst:
            for i in range(1, src.count + 1):
                dst.write(src.read(i), i)

print("✅ All GeoTIFFs compressed and saved to:", output_folder)

# %%
import os
import rasterio
from rasterio.enums import Compression
from tqdm import tqdm

# Set input and output folder paths
input_folder = r"G:\Public\GLC_FCS30D\After_20th_Centry\2008"
output_folder = os.path.join(input_folder, "compressed")
os.makedirs(output_folder, exist_ok=True)

# Loop through all .tif files in the folder
tif_files = [f for f in os.listdir(input_folder) if f.lower().endswith(".tif")]

for filename in tqdm(tif_files, desc="Compressing TIFFs"):
    input_path = os.path.join(input_folder, filename)
    output_path = os.path.join(output_folder, filename)

    with rasterio.open(input_path) as src:
        profile = src.profile
        profile.update(compress='lzw')

        with rasterio.open(output_path, 'w', **profile) as dst:
            for i in range(1, src.count + 1):
                dst.write(src.read(i), i)

print("✅ All GeoTIFFs compressed and saved to:", output_folder)

# %%
import os
import rasterio
from rasterio.enums import Compression
from tqdm import tqdm

# Set input and output folder paths
input_folder = r"G:\Public\GLC_FCS30D\After_20th_Centry\2009"
output_folder = os.path.join(input_folder, "compressed")
os.makedirs(output_folder, exist_ok=True)

# Loop through all .tif files in the folder
tif_files = [f for f in os.listdir(input_folder) if f.lower().endswith(".tif")]

for filename in tqdm(tif_files, desc="Compressing TIFFs"):
    input_path = os.path.join(input_folder, filename)
    output_path = os.path.join(output_folder, filename)

    with rasterio.open(input_path) as src:
        profile = src.profile
        profile.update(compress='lzw')

        with rasterio.open(output_path, 'w', **profile) as dst:
            for i in range(1, src.count + 1):
                dst.write(src.read(i), i)

print("✅ All GeoTIFFs compressed and saved to:", output_folder)

# %%
import os
import rasterio
from rasterio.enums import Compression
from tqdm import tqdm

# Set input and output folder paths
input_folder = r"G:\Public\GLC_FCS30D\After_20th_Centry\2010"
output_folder = os.path.join(input_folder, "compressed")
os.makedirs(output_folder, exist_ok=True)

# Loop through all .tif files in the folder
tif_files = [f for f in os.listdir(input_folder) if f.lower().endswith(".tif")]

for filename in tqdm(tif_files, desc="Compressing TIFFs"):
    input_path = os.path.join(input_folder, filename)
    output_path = os.path.join(output_folder, filename)

    with rasterio.open(input_path) as src:
        profile = src.profile
        profile.update(compress='lzw')

        with rasterio.open(output_path, 'w', **profile) as dst:
            for i in range(1, src.count + 1):
                dst.write(src.read(i), i)

print("✅ All GeoTIFFs compressed and saved to:", output_folder)

# %%
import os
import rasterio
from rasterio.enums import Compression
from tqdm import tqdm

# Set input and output folder paths
input_folder = r"G:\Public\GLC_FCS30D\After_20th_Centry\2011"
output_folder = os.path.join(input_folder, "compressed")
os.makedirs(output_folder, exist_ok=True)

# Loop through all .tif files in the folder
tif_files = [f for f in os.listdir(input_folder) if f.lower().endswith(".tif")]

for filename in tqdm(tif_files, desc="Compressing TIFFs"):
    input_path = os.path.join(input_folder, filename)
    output_path = os.path.join(output_folder, filename)

    with rasterio.open(input_path) as src:
        profile = src.profile
        profile.update(compress='lzw')

        with rasterio.open(output_path, 'w', **profile) as dst:
            for i in range(1, src.count + 1):
                dst.write(src.read(i), i)

print("✅ All GeoTIFFs compressed and saved to:", output_folder)

# %%
import os
import rasterio
from rasterio.enums import Compression
from tqdm import tqdm

# Set input and output folder paths
input_folder = r"G:\Public\GLC_FCS30D\After_20th_Centry\2012"
output_folder = os.path.join(input_folder, "compressed")
os.makedirs(output_folder, exist_ok=True)

# Loop through all .tif files in the folder
tif_files = [f for f in os.listdir(input_folder) if f.lower().endswith(".tif")]

for filename in tqdm(tif_files, desc="Compressing TIFFs"):
    input_path = os.path.join(input_folder, filename)
    output_path = os.path.join(output_folder, filename)

    with rasterio.open(input_path) as src:
        profile = src.profile
        profile.update(compress='lzw')

        with rasterio.open(output_path, 'w', **profile) as dst:
            for i in range(1, src.count + 1):
                dst.write(src.read(i), i)

print("✅ All GeoTIFFs compressed and saved to:", output_folder)

# %%
import os
import rasterio
from rasterio.enums import Compression
from tqdm import tqdm

# Set input and output folder paths
input_folder = r"G:\Public\GLC_FCS30D\After_20th_Centry\2018"
output_folder = os.path.join(input_folder, "compressed")
os.makedirs(output_folder, exist_ok=True)

# Loop through all .tif files in the folder
tif_files = [f for f in os.listdir(input_folder) if f.lower().endswith(".tif")]

for filename in tqdm(tif_files, desc="Compressing TIFFs"):
    input_path = os.path.join(input_folder, filename)
    output_path = os.path.join(output_folder, filename)

    with rasterio.open(input_path) as src:
        profile = src.profile
        profile.update(compress='lzw')

        with rasterio.open(output_path, 'w', **profile) as dst:
            for i in range(1, src.count + 1):
                dst.write(src.read(i), i)

print("✅ All GeoTIFFs compressed and saved to:", output_folder)

# %%
import os
import rasterio
from rasterio.enums import Compression
from tqdm import tqdm

# Set input and output folder paths
input_folder = r"G:\Public\GLC_FCS30D\After_20th_Centry\2019"
output_folder = os.path.join(input_folder, "compressed")
os.makedirs(output_folder, exist_ok=True)

# Loop through all .tif files in the folder
tif_files = [f for f in os.listdir(input_folder) if f.lower().endswith(".tif")]

for filename in tqdm(tif_files, desc="Compressing TIFFs"):
    input_path = os.path.join(input_folder, filename)
    output_path = os.path.join(output_folder, filename)

    with rasterio.open(input_path) as src:
        profile = src.profile
        profile.update(compress='lzw')

        with rasterio.open(output_path, 'w', **profile) as dst:
            for i in range(1, src.count + 1):
                dst.write(src.read(i), i)

print("✅ All GeoTIFFs compressed and saved to:", output_folder)
